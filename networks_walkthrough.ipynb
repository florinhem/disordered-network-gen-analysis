# %% [markdown]
# First, import the network generation and analysis modules.

# %%
# include file where structure analysis modules are stored
include("structure_analysis_modules.jl")

# import my module that contains all functions for the generation and analysis of networks
import .NetworkGeneration as NG
import .NetworkAnalysis as NA
import .GeneralUtilities as GU

import Plots
import MetaGraphsNext
# Out:
# WARNING: replacing module GeneralUtilities.
# WARNING: replacing module BinaryDataAnalysis.
# WARNING: replacing module NetworkGeneration.
# WARNING: replacing module NetworkAnalysis.

# %% [markdown]
# # Network generation
#
# ## Basics
# We start by generating a MetaGraph object which will contain all the information about our spatial network. The initial network is periodic and can be a diamond, primitive cubic, BCC and FCC network (more precisely, this should say dia, pcu, bcu and fcu).

# %%
evolution_dict = NA.get_evolution_dict(;nr_vertices = 216, network_type="diamond", bond_bending_const=0.285, min_ring_size=3)
spatial_network = NG.get_periodic_network(evolution_dict)
# Out:
# Meta graph based on a Graphs.SimpleGraphs.SimpleGraph{Int64} with vertex labels of type Int64, vertex metadata of type Dict{String, Vector{Float64}}, edge metadata of type Dict{String, Union{Float64, Vector{Float64}}}, graph metadata given by Dict{String, Any}("bond_bending_const" => 0.285, "total_energy_up_to_date" => true, "supercell_edge_length" => 6.9282032302755105, "coordination_nr" => 4, "nr_dimensions" => 3, "theta_ground_state" => 109.5, "nr_vertices" => 216, "total_energy" => 44.153423851698), and default weight 1.0

# %% [markdown]
# We can visualize the initial network (this will open in a new window).

# %%
NG.plot_spatial_network(spatial_network)
# Out:
# MethodError: no method matching return_type(::AbstractPlotting.var"#30#32"{Set{AbstractPlotting.Mouse.Button}}, ::Tuple{DataType})
#
#
#
# Closest candidates are:
#
#   return_type(::Any, !Matched::DataType, !Matched::UInt64)
#
#    @ Core compiler\typeinfer.jl:1107
#
#   return_type(::Any, !Matched::DataType)
#
#    @ Core compiler\typeinfer.jl:1101
#
#
#
#
#
# Stacktrace:
#
#   [1] _sanitize_observer_function(f::Any, argtypes::Tuple{DataType})
#
#     @ AbstractPlotting C:\Users\GlauserV\.julia\packages\AbstractPlotting\2A5iv\src\interaction\PriorityObservable.jl:82
#
#   [2] on(f::Any, observable::AbstractPlotting.PriorityObservable{AbstractPlotting.MouseButtonEvent}; weak::Bool, priority::Int8)
#
#     @ AbstractPlotting C:\Users\GlauserV\.julia\packages\AbstractPlotting\2A5iv\src\interaction\PriorityObservable.jl:100
#
#   [3] on
#
#     @ C:\Users\GlauserV\.julia\packages\AbstractPlotting\2A5iv\src\interaction\PriorityObservable.jl:99 [inlined]
#
#   [4] AbstractPlotting.Events()
#
#     @ AbstractPlotting C:\Users\GlauserV\.julia\packages\AbstractPlotting\2A5iv\src\types.jl:109
#
#   [5] AbstractPlotting.Scene(; clear::Bool, transform_func::Function, scene_attributes::@Kwargs{camera::typeof(AbstractPlotting.campixel!)})
#
#     @ AbstractPlotting C:\Users\GlauserV\.julia\packages\AbstractPlotting\2A5iv\src\scenes.jl:135
#
#   [6] AbstractPlotting.Figure(; kwargs::@Kwargs{})
#
#     @ AbstractPlotting C:\Users\GlauserV\.julia\packages\AbstractPlotting\2A5iv\src\figures.jl:70
#
#   [7] Figure
#
#     @ C:\Users\GlauserV\.julia\packages\AbstractPlotting\2A5iv\src\figures.jl:65 [inlined]
#
#   [8] plot(P::Type{AbstractPlotting.Combined{GraphMakie.graphplot}}, args::MetaGraphsNext.MetaGraph{Int64, Graphs.SimpleGraphs.SimpleGraph{Int64}, Int64, Dict{String, Vector{Float64}}, Dict{String, Union{Float64, Vector{Float64}}}, Dict{String, Any}, MetaGraphsNext.var"#11#13", Float64}; axis::@NamedTuple{}, figure::@NamedTuple{}, kw_attributes::@Kwargs{})
#
#     @ AbstractPlotting C:\Users\GlauserV\.julia\packages\AbstractPlotting\2A5iv\src\figureplotting.jl:18
#
#   [9] plot
#
#     @ C:\Users\GlauserV\.julia\packages\AbstractPlotting\2A5iv\src\figureplotting.jl:16 [inlined]
#
#  [10] #graphplot#1
#
#     @ C:\Users\GlauserV\.julia\packages\AbstractPlotting\2A5iv\src\recipes.jl:12 [inlined]
#
#  [11] graphplot
#
#     @ C:\Users\GlauserV\.julia\packages\AbstractPlotting\2A5iv\src\recipes.jl:11 [inlined]
#
#  [12] plot_spatial_network(spatial_network::MetaGraphsNext.MetaGraph{Int64, Graphs.SimpleGraphs.SimpleGraph{Int64}, Int64, Dict{String, Vector{Float64}}, Dict{String, Union{Float64, Vector{Float64}}}, Dict{String, Any}, MetaGraphsNext.var"#11#13", Float64}; highlight_nodes::Tuple{}, highlight_edges::Vector{Any})
#
#     @ Main.NetworkGeneration c:\Users\GlauserV\OneDrive - Université de Fribourg\Anlagen\AMI\Projekt\GitFlorin\code_photonic_structures\networks\network_plotting.jl:241
#
#  [13] plot_spatial_network(spatial_network::MetaGraphsNext.MetaGraph{Int64, Graphs.SimpleGraphs.SimpleGraph{Int64}, Int64, Dict{String, Vector{Float64}}, Dict{String, Union{Float64, Vector{Float64}}}, Dict{String, Any}, MetaGraphsNext.var"#11#13", Float64})
#
#     @ Main.NetworkGeneration c:\Users\GlauserV\OneDrive - Université de Fribourg\Anlagen\AMI\Projekt\GitFlorin\code_photonic_structures\networks\network_plotting.jl:214
#
#  [14] top-level scope
#
#     @ c:\Users\GlauserV\OneDrive - Université de Fribourg\Anlagen\AMI\Projekt\GitFlorin\code_photonic_structures\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W5sZmlsZQ==.jl:1

# %% [markdown]
# The network has some general properties which are stored as a dictionary and can be accessed as follows.

# %%
spatial_network[]
# Out:
# Dict{String, Any} with 7 entries:
#   "bond_bending_const"      => 0.285
#   "total_energy_up_to_date" => true
#   "supercell_edge_length"   => 6.9282
#   "coordination_nr"         => 4
#   "nr_dimensions"           => 3
#   "nr_vertices"             => 416
#   "total_energy"            => 8.49154e-29

# %% [markdown]
# Furthermore, information about its vertices (or nodes) and bonds (or edges) can be accessed in the following way.

# %%
println(spatial_network[1])
println(collect(MetaGraphsNext.neighbor_labels(spatial_network, 1)))
println(spatial_network[1,24])
# Out:
# Dict("position" => [0.2886751345948129, 0.2886751345948129, 0.2886751345948129])
# [217, 219, 221, 223]
# KeyError: key (1, 24) not found
#
#
#
# Stacktrace:
#
#  [1] getindex
#
#    @ .\dict.jl:498 [inlined]
#
#  [2] getindex(meta_graph::MetaGraphsNext.MetaGraph{Int64, Graphs.SimpleGraphs.SimpleGraph{Int64}, Int64, Dict{String, Vector{Float64}}, Dict{String, Union{Float64, Vector{Float64}}}, Dict{String, Any}, MetaGraphsNext.var"#11#13", Float64}, label_1::Int64, label_2::Int64)
#
#    @ MetaGraphsNext C:\Users\GlauserV\.julia\packages\MetaGraphsNext\KWB3R\src\dict_utils.jl:25
#
#  [3] top-level scope
#
#    @ c:\Users\GlauserV\OneDrive - Université de Fribourg\Anlagen\AMI\Projekt\GitFlorin\code_photonic_structures\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X12sZmlsZQ==.jl:3

# %% [markdown]
# For more details, consider the documentation of the `MetaGraphsNext` package: https://juliagraphs.org/MetaGraphsNext.jl/stable/

# %% [markdown]
# Now, we can perform one Monte Carlo move which consists of switching a bond and relaxing the network. The temperature parameter controls, how likely a bond switch is to be accepted. At $T=0$, only a decrease in total Keating energy is allowed. Since we start from the ground state, this is not possible initially. We choose a high temperature which favors an increase in energy to be allowed. A note on the Keating energy and units. The Keating energy is defined in 10.1103/PhysRev.145.637 and further explained in 10.1103/PhysRevB.62.4985. All energies will be given in units of $\alpha d^2$ where $\alpha$ is the bond-stretching force constant and $d$ is the ground state bond length. Temperatures are given in units of $\alpha d^2/k_\mathrm{B}$ where $k_\mathrm{B}$ is the Boltzmann constant.

# %%
temperature = 10

spatial_network, move_accepted = NG.monte_carlo_move!(
    spatial_network, 
    evolution_dict,
    temperature)

println("Move accepted: ", move_accepted)
NG.plot_spatial_network(spatial_network)
# Out:
# BoundsError: attempt to access 1-element Vector{Int64} at index [2]
#
#
#
# Stacktrace:
#
#  [1] getindex(A::Vector{Int64}, i1::Int64)
#
#    @ Base .\essentials.jl:13
#
#  [2] local_bond_bending_energy_keating(spatial_network::MetaGraphsNext.MetaGraph{Int64, Graphs.SimpleGraphs.SimpleGraph{Int64}, Int64, Dict{String, Vector{Float64}}, Dict{String, Union{Float64, Vector{Float64}}}, Dict{String, Any}, MetaGraphsNext.var"#11#13", Float64}, vertex_label::Int64)
#
#    @ Main.NetworkGeneration c:\Users\GlauserV\OneDrive - Université de Fribourg\Anlagen\AMI\Projekt\GitFlorin\code_photonic_structures\networks\network_energy_calculation.jl:37
#
#  [3] get_total_energy_keating(spatial_network::MetaGraphsNext.MetaGraph{Int64, Graphs.SimpleGraphs.SimpleGraph{Int64}, Int64, Dict{String, Vector{Float64}}, Dict{String, Union{Float64, Vector{Float64}}}, Dict{String, Any}, MetaGraphsNext.var"#11#13", Float64})
#
#    @ Main.NetworkGeneration c:\Users\GlauserV\OneDrive - Université de Fribourg\Anlagen\AMI\Projekt\GitFlorin\code_photonic_structures\networks\network_energy_calculation.jl:98
#
#  [4] monte_carlo_move!(spatial_network::MetaGraphsNext.MetaGraph{Int64, Graphs.SimpleGraphs.SimpleGraph{Int64}, Int64, Dict{String, Vector{Float64}}, Dict{String, Union{Float64, Vector{Float64}}}, Dict{String, Any}, MetaGraphsNext.var"#11#13", Float64}, evolution_dict::Dict{String, Any}, temperature::Int64; switched_chain::NTuple{4, Int64})
#
#    @ Main.NetworkGeneration c:\Users\GlauserV\OneDrive - Université de Fribourg\Anlagen\AMI\Projekt\GitFlorin\code_photonic_structures\networks\network_modification.jl:666
#
#  [5] monte_carlo_move!(spatial_network::MetaGraphsNext.MetaGraph{Int64, Graphs.SimpleGraphs.SimpleGraph{Int64}, Int64, Dict{String, Vector{Float64}}, Dict{String, Union{Float64, Vector{Float64}}}, Dict{String, Any}, MetaGraphsNext.var"#11#13", Float64}, evolution_dict::Dict{String, Any}, temperature::Int64)
#
#    @ Main.NetworkGeneration c:\Users\GlauserV\OneDrive - Université de Fribourg\Anlagen\AMI\Projekt\GitFlorin\code_photonic_structures\networks\network_modification.jl:657
#
#  [6] top-level scope
#
#    @ c:\Users\GlauserV\OneDrive - Université de Fribourg\Anlagen\AMI\Projekt\GitFlorin\code_photonic_structures\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:3

# %% [markdown]
# We can evolve the network for a given number of Monte Carlo moves (that is attempted bond switches).

# %%
nr_attempted_bond_switches = 10

spatial_network, total_energy_vec, move_accepted_vec = NG.evolve_network!(
    spatial_network,
    evolution_dict,
    nr_attempted_bond_switches, 
    temperature;
    print_progress = true,
    print_every_nr_attempted_bond_switches = 10)

Plots.plot(total_energy_vec, xlabel="Monte Carlo move", ylabel="Total energy", label="Total energy")
# Out:
# ArgumentError: collection must be non-empty
#
#
#
# Stacktrace:
#
#  [1] SamplerRangeNDL
#
#    @ C:\Users\GlauserV\.julia\juliaup\julia-1.10.5+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Random\src\generation.jl:333 [inlined]
#
#  [2] Sampler
#
#    @ C:\Users\GlauserV\.julia\juliaup\julia-1.10.5+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Random\src\generation.jl:189 [inlined]
#
#  [3] Sampler
#
#    @ C:\Users\GlauserV\.julia\juliaup\julia-1.10.5+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Random\src\generation.jl:418 [inlined]
#
#  [4] Sampler
#
#    @ C:\Users\GlauserV\.julia\juliaup\julia-1.10.5+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Random\src\Random.jl:139 [inlined]
#
#  [5] rand
#
#    @ C:\Users\GlauserV\.julia\juliaup\julia-1.10.5+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Random\src\Random.jl:255 [inlined]
#
#  [6] rand
#
#    @ C:\Users\GlauserV\.julia\juliaup\julia-1.10.5+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Random\src\Random.jl:260 [inlined]
#
#  [7] get_random_chain(spatial_network::MetaGraphsNext.MetaGraph{Int64, Graphs.SimpleGraphs.SimpleGraph{Int64}, Int64, Dict{String, Vector{Float64}}, Dict{String, Union{Float64, Vector{Float64}}}, Dict{String, Any}, MetaGraphsNext.var"#11#13", Float64}; declined_chains::Vector{Any}, remaining_chains::Vector{Any}, seed::Nothing, min_ring_size::Int64)
#
#    @ Main.NetworkGeneration c:\Users\GlauserV\OneDrive - Université de Fribourg\Anlagen\AMI\Projekt\GitFlorin\code_photonic_structures\networks\network_utilities.jl:484
#
#  [8] evolve_network!(spatial_network::MetaGraphsNext.MetaGraph{Int64, Graphs.SimpleGraphs.SimpleGraph{Int64}, Int64, Dict{String, Vector{Float64}}, Dict{String, Union{Float64, Vector{Float64}}}, Dict{String, Any}, MetaGraphsNext.var"#11#13", Float64}, evolution_dict::Dict{String, Any}, nr_attempted_bond_switches::Int64, temperature::Int64; declined_chains::Vector{Any}, remaining_chains::Vector{Any}, total_energy_vec::Vector{Float64}, move_accepted_vec::Vector{Bool}, print_progress::Bool, print_every_nr_attempted_bond_switches::Int64, random_evolution_seed::Int64, quench_counter::Int64, print_lock::ReentrantLock)
#
#    @ Main.NetworkGeneration c:\Users\GlauserV\OneDrive - Université de Fribourg\Anlagen\AMI\Projekt\GitFlorin\code_photonic_structures\networks\network_modification.jl:802
#
#  [9] top-level scope
#
#    @ c:\Users\GlauserV\OneDrive - Université de Fribourg\Anlagen\AMI\Projekt\GitFlorin\code_photonic_structures\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X20sZmlsZQ==.jl:3

# %% [markdown]
# Let's visualize the network again.

# %%
NG.plot_spatial_network(spatial_network)

# %% [markdown]
# Usually, we want to set a temperature sequence to heat and/or cool the network. After the heating and cooling and nonzero temperature, we typically quench the network. That is we evolve the network at $T=0$ until no single bond switch can reduce the total energy any more. Note that one Monte Carlo step is defined as the number of Monte Carlo moves where on average, every bond chain was attempted once. For a network with $N$ vertices, in 10.1103/PhysRevB.62.4985, they state: 'A combination of four atoms ABCD with bonds AB, BC, and CD can be selected in $N \cdot 4 \cdot 3 \cdot 3/2$ times, so there are 18N possible bond transpositions.'. If we want to increase the temperature very quickly, we set the gradient to $T/N_\mathrm{MC}=10 \alpha d^2/k_\mathrm{B}$. The argument `nr_monte_carlo_steps_per_temperature` sets the resolution how finely the temperature should be increased. A default value of $0.01$ typically works well.

# %%
maximal_temperature = 0.1

temperature_vec, nr_monte_carlo_steps_per_temperature_vec = NA.get_temperature_sequence_heating_cooling_gradient(maximal_temperature;
            temperature_gradient = 10.0, 
            nr_monte_carlo_steps_per_temperature = 2/(18*216),
            quench = false )

length(temperature_vec)
# Out:
# 39

# %%
evolution_dict["temperature_vec"] = temperature_vec
evolution_dict["nr_monte_carlo_steps_per_temperature_vec"] = nr_monte_carlo_steps_per_temperature_vec

spatial_network, total_energy_vec, move_accepted_vec = NG.evolve_network_temperature_sequence!(
    spatial_network,
    evolution_dict;
    total_energy_vec = total_energy_vec,
    move_accepted_vec= move_accepted_vec,
    print_progress = true,
    print_every_nr_attempted_bond_switches = 100)
# Out:
# UndefVarError: `total_energy_vec` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ c:\Users\GlauserV\OneDrive - Université de Fribourg\Anlagen\AMI\Projekt\GitFlorin\code_photonic_structures\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X25sZmlsZQ==.jl:4

# %% [markdown]
# Let us save the generated network to a GML file which can, for example, be loaded by Python's `Networkx` package.

# %%
save_path = raw".\my_networks\\"
filename = "example_network"

NG.save_spatial_network_to_gml(
    spatial_network,
    filename;
    evolution_dict = evolution_dict,
    save_path = save_path)

# %% [markdown]
# Loading the network and the evolution dictionary works as follows.

# %%
spatial_network = NG.load_spatial_network_from_gml(save_path*filename*".gml")
evolution_dict = GU.load_h5_dict(save_path*filename*"_evolution.h5")
# Out:
# Dict{String, Any} with 20 entries:
#   "bond_bending_const"      => 0.285
#   "nr_max_relaxation_cycle… => 25
#   "nr_monte_carlo_steps_pe… => [0.000514403, 0.000514403, 0.000514403, 0.000514…
#   "temperature_vec"         => [0.0, 0.00514403, 0.0102881, 0.0154321, 0.020576…
#   "inefficient_optimizatio… => "newton"
#   "estimated_nr_bond_switc… => 77760
#   "nr_vertices"             => 216
#   "reject_during_relaxatio… => 5
#   "thermal_fluctuations"    => false
#   "min_ring_size"           => 3
#   "mean_nr_monte_carlo_ste… => 13.7
#   "shell_nr"                => 4
#   "relax_efficiently"       => true
#   "break_at_relative_clust… => 0.0001
#   "nr_dimensions"           => 3
#   "network_type"            => "diamond"
#   "relaxation_optimization… => 1
#   "relaxation_overshoot_fa… => 1.5
#   "relax_globally_after_th… => true
#   "random_evolution_seed"   => -1

# %% [markdown]
# The vertices and bonds in the spatial network are connected using periodic boundary conditions. If we want to plot the network or run an optical simulation with it, we need to transform the network by adding virtual vertices outside the supercell and connecting the vertices close to the cell edges to those virtual vertices. Furthermore, if a bond sits close to the edge and we want to assign a cylinder to it, we need to duplicate the bond on the other site of the supercell just outside of the simulation box. These actions can be performed using the following function.

# %%
spatial_network = NG.get_spatial_network_for_simulation(
    spatial_network;
    vector_out_of_supercell_length = 1,
    duplicate_bonds_close_to_supercell_edge = true,
    bond_radius = 0.35,
    save_result = true,
    filename = filename,
    save_path = save_path)
# Out:
# Meta graph based on a Graphs.SimpleGraphs.SimpleGraph{Int64} with vertex labels of type Int64, vertex metadata of type Dict{String, Any}, edge metadata of type Dict{String, Any}, graph metadata given by Dict{String, Any}("bond_bending_const" => 0.285, "total_energy_up_to_date" => false, "supercell_edge_length" => 6.9282032302755105, "coordination_nr" => 4, "nr_dimensions" => 3, "nr_vertices" => 718, "total_energy" => 8.491539139856031e-29), and default weight 1.0

# %%
spatial_network[]
# Out:
# Dict{String, Any} with 7 entries:
#   "bond_bending_const"      => 0.285
#   "total_energy_up_to_date" => false
#   "supercell_edge_length"   => 6.9282
#   "coordination_nr"         => 4
#   "nr_dimensions"           => 3
#   "nr_vertices"             => 718
#   "total_energy"            => 8.49154e-29

# %% [markdown]
# In case, we want to export a given network as a file that can be handled by Blender or another rendering software, we can create cylinder meshes for all bonds. For this we need to set a radius which is passed in units of the equilibrium bond length $d$.

# %%
save_path = raw".\my_networks\geometrical_models\\"
filename = "example_network"

NG.save_mesh_from_spatial_network(
    spatial_network, 
    filename;
    bond_radius = 0.35,
    vector_out_of_supercell_length = 1,
    save_path = save_path,
    duplicate_bonds_close_to_supercell_edge = true,
    format = "obj")

# %% [markdown]
# ## Parallel network generation
#
# There are two functions implemented to generate networks in parallel on multiple threads. For this, we first need to generate the evolution dictionaries of multiple networks and save them locally.

# %%
maximal_temperatures = [0.11, 0.12]
temperature_gradient = 0.1
nr_vertices = 216
bond_bending_const = 0.285
evolution_dicts_directory_path = raw".\my_networks\my_evolution_dicts\\"

for maximal_temperature in maximal_temperatures
    temperature_vec, nr_monte_carlo_steps_per_temperature_vec = NA.get_temperature_sequence_heating_cooling_gradient(
        maximal_temperature;
        temperature_gradient = 10.0, 
        nr_monte_carlo_steps_per_temperature = 2/3888,
        quench = false )
    evolution_dict = NA.get_evolution_dict(;nr_vertices = nr_vertices ,temperature_vec = temperature_vec,
        nr_monte_carlo_steps_per_temperature_vec = nr_monte_carlo_steps_per_temperature_vec, min_ring_size = 3,
        bond_bending_const = bond_bending_const)
    filename = string(nr_vertices)*"_vertices_T_"*string(maximal_temperature)*"_heat_cool_"*string(temperature_gradient)*"_per_mc"
    GU.save_dict_to_h5(evolution_dict, evolution_dicts_directory_path*filename*"_evolution.h5")
end

# %% [markdown]
# Now, we need to run Julia in multi-threaded mode. E. g., if we want to run two threads in parallel, one for each of the two networks, we can use the Linux command `\$ julia --threads 2`. More infos about multi-threading in Julia can be found on https://docs.julialang.org/en/v1/manual/multi-threading/

# %% [markdown]
# If we simply want to evolve one network for each evolution dictionary, we can use the following function. The combination of the arguments `save_network_after_each_temperature` and `further_evolve_previous_networks` can be used to save checkpoint networks after each temperature and further evolve from the last saved network. The print lock is needed, such that the multiple threads print their individual progress after each other.

# %%
save_path = raw".\my_networks\\"

NG.generate_spatial_networks_from_evolution_dicts_in_directory(
    evolution_dicts_directory_path,
    save_path;
    print_every_nr_attempted_bond_switches = 10,
    print_progress = true,
    save_network_after_each_temperature = false,
    further_evolve_previous_networks = false,
    print_lock = Threads.ReentrantLock())
# Out:
# ArgumentError: cannot create partitions of length 0
#
#
#
# Stacktrace:
#
#  [1] partition
#
#    @ .\iterators.jl:1270 [inlined]
#
#  [2] generate_spatial_networks_from_evolution_dicts_in_directory(evolution_dicts_directory_path::String, save_path::String; print_every_nr_attempted_bond_switches::Int64, print_progress::Bool, random_evolution_seed::Int64, save_network_after_each_temperature::Bool, further_evolve_previous_networks::Bool, print_lock::ReentrantLock)
#
#    @ Main.NetworkGeneration c:\Users\GlauserV\OneDrive - Université de Fribourg\Anlagen\AMI\Projekt\GitFlorin\code_photonic_structures\networks\network_io.jl:383
#
#  [3] top-level scope
#
#    @ c:\Users\GlauserV\OneDrive - Université de Fribourg\Anlagen\AMI\Projekt\GitFlorin\code_photonic_structures\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X45sZmlsZQ==.jl:3

# %% [markdown]
# In case we want to evolve several networks for each evolution dict, we can use the following function. Due to the random sampling that is inherent to any Monte Carlo method, the networks will evolve with the same conditions and the same temperature profile, but with a different sequence of bond switched and will, therefore, yield different outcomes. __Note that this function currently only runs on Linux machines!__

# %%
NG.generate_spatial_networks_from_evolution_dicts_in_directory_multiple_runs(
    evolution_dicts_directory_path,
    save_path;
    print_every_nr_attempted_bond_switches = 10,
    print_progress = true,
    save_network_after_each_temperature = false,
    further_evolve_previous_networks = false,
    print_lock = Threads.ReentrantLock(),
    runs_vec = collect(1:4))

# %% [markdown]
# # Network analysis
# The are plenty of metrics and functions available to characterize networks and to measure their order. They can be divided into two classes. On the one hand, there are those metrics that characterize spatial networks, that is a collection of vertices in space and bonds between them. On the other hand, there are metrics for two-phase media which will typically be provided as voxelized arrays. When running the function `get_all_dicts_from_network_single_file`, a plethora of both kinds of order metrics is calculated for the given network. __Note: The following command can take a few minutes to run.__

# %%
filename = "example_network"
spatial_network_path = raw".\my_networks\\"
structure_dict_path = raw".\my_networks\binary_structures\\"
analysis_data_path = raw".\my_networks\analyis_data\\"

NA.get_all_dicts_from_network_single_file(
    filename,
    spatial_network_path,
    structure_dict_path,
    analysis_data_path;
    bond_radius = 0.35,
    voxel_edge_length = 0.25,
    print_progress = true,
    print_lock = Threads.ReentrantLock())
# Out:
# Autocovariance function calculation progress
#                     thread nr 1: 3.4 %
# Autocovariance function calculation progress
#                     thread nr 1: 6.9 %
# Autocovariance function calculation progress
#                     thread nr 1: 10.3 %
# Autocovariance function calculation progress
#                     thread nr 1: 13.8 %
# Autocovariance function calculation progress
#                     thread nr 1: 17.2 %
# Autocovariance function calculation progress
#                     thread nr 1: 20.7 %
# Autocovariance function calculation progress
#                     thread nr 1: 24.1 %
# Autocovariance function calculation progress
#                     thread nr 1: 27.6 %
# Autocovariance function calculation progress
#                     thread nr 1: 31.0 %
# Autocovariance function calculation progress
#                     thread nr 1: 34.5 %
# Autocovariance function calculation progress
#                     thread nr 1: 37.9 %
# Autocovariance function calculation progress
#                     thread nr 1: 41.4 %
# Autocovariance function calculation progress
#                     thread nr 1: 44.8 %
# Autocovariance function calculation progress
#                     thread nr 1: 48.3 %
# Autocovariance function calculation progress
#                     thread nr 1: 51.7 %
# Autocovariance function calculation progress
#                     thread nr 1: 55.2 %
# Autocovariance function calculation progress
#                     thread nr 1: 58.6 %
# Autocovariance function calculation progress
#                     thread nr 1: 62.1 %
# Autocovariance function calculation progress
#                     thread nr 1: 65.5 %
# Autocovariance function calculation progress
#                     thread nr 1: 69.0 %
# Autocovariance function calculation progress
#                     thread nr 1: 72.4 %
# Autocovariance function calculation progress
#                     thread nr 1: 75.9 %
# Autocovariance function calculation progress
#                     thread nr 1: 79.3 %
# Autocovariance function calculation progress
#                     thread nr 1: 82.8 %
# Autocovariance function calculation progress
#                     thread nr 1: 86.2 %
# Autocovariance function calculation progress
#                     thread nr 1: 89.7 %
# Autocovariance function calculation progress
#                     thread nr 1: 93.1 %
# Autocovariance function calculation progress
#                     thread nr 1: 96.6 %

# %% [markdown]
# As one might have noticed, some of the metrics are quite computationally expensive to be calculated. These are especially the autocovariance function and the pore size distribution which analyize the voxelized two-phase medium data. It is therefore encouraged to analyze multiple networks in a parallelized fashion. As explained above, for this, julia can be run in multi-threaded mode. __Note: The following command again only runs on a Linux machine.__

# %%
if(Sys.islinux())
    NA.get_all_dicts_from_networks_multithreading(
        spatial_network_path,
        structure_dict_path,
        analysis_data_path;
        bond_radius = 0.35,
        voxel_edge_length = 0.25,
        print_progress = true,
        print_lock = Threads.ReentrantLock(),
        runs_vec = collect(1:5))
end
